# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("./rawdata/archive/2009.csv")

# %%
# import pandas as pd
# import glob
# path = "./rawdata/archive" # use your path
  
# all_files = glob.glob(path + "/*.csv")
# li = []
# for filename in all_files:
#     print(filename)
#     frame = pd.read_csv(filename, index_col=None, header=0)
#     li.append(frame)
# df = pd.concat(li, axis=0, ignore_index=True)

# %%
df["ROUTE"] = df["ORIGIN"] + "," + df["DEST"]

# %%
df.head(100)
# Out:
#        FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0   2009-01-01         XE               1204    DCA  EWR          1100
# 1   2009-01-01         XE               1206    EWR  IAD          1510
# 2   2009-01-01         XE               1207    EWR  DCA          1100
# 3   2009-01-01         XE               1208    DCA  EWR          1240
# 4   2009-01-01         XE               1209    IAD  EWR          1715
# ..         ...        ...                ...    ...  ...           ...
# 95  2009-01-01         XE               2118    CLE  ALB          1855
# 96  2009-01-01         XE               2119    MCI  IAH           940
# 97  2009-01-01         XE               2120    MKE  IAH          1423
# 98  2009-01-01         XE               2126    CMH  EWR          1715
# 99  2009-01-01         XE               2128    CLE  LGA          1546
#
#     DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  TAXI_IN  \
# ...

# %%
df.to_csv("decade_flights.csv")

# %%
df.drop(df.columns.difference(["FL_DATE","OP_CARRIER","ORIGIN","DEST","CRS_ELAPSED_TIME","ACTUAL_ELAPSED_TIME","AIR_TIME","DISTANCE","ROUTE"]), 1, inplace=True)

# %%
df = df[df["ROUTE"] == df["ROUTE"][0]]

# %%
df.head(100)

# %%
df["ACTUAL_ELAPSED_TIME"].plt.hist

# %%
ax = df.hist(column='ACTUAL_ELAPSED_TIME', bins=100, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)

# %%
df["ACTUAL_ELAPSED_TIME"].hist(cumulative=True, density=1, bins=1000)

# %%
df["ACTUAL_ELAPSED_TIME"].max()
